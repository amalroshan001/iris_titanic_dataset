# %% [markdown]
# # IRIS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.  How many samples and features are there in the Iris dataset?

# %%
pd.set_option("display.min_rows",50)

# %%
iris=pd.read_csv("Iris.csv.xls")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# ..   ...            ...           ...            ...           ...
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# ..              ...
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### 2. What are the names of the features (columns) in the dataset?

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ### 3. How many unique species of iris flowers are present in the dataset?

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### 4. What is the average sepal length for each species of iris?

# %%
iris["SepalLengthCm"].mean()
# Out:
# 5.843333333333334

# %% [markdown]
# ### 5. What is the maximum petal width among all the iris flowers?

# %%
iris['PetalWidthCm'].max()
# Out:
# 2.5

# %% [markdown]
# ### 6. How many samples belong to each species of iris?

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ### 7. How many samples have a petal length greater than 5 cm?

# %%
iris[iris['PetalLengthCm']>5]['PetalLengthCm'].value_counts().sum()
# Out:
# 42

# %% [markdown]
# ### 8. How can you filter and display only the samples belonging to a specific species, e.g., Iris setosa?

# %%
iris[iris['Species']=='Iris-setosa']
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa
# 34  35            4.9           3.1            1.5           0.1  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa
# 37  38            4.9           3.1            1.5           0.1  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 39  40            5.1           3.4            1.5           0.2  Iris-setosa
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
# 48  49            5.3           3.7            1.5           0.2  Iris-setosa
# 49  50            5.0           3.3            1.4           0.2  Iris-setosa

# %% [markdown]
# ### 9. What is the minimum and maximum sepal length among Iris setosa flowers?

# %%
iris[iris['Species']=='Iris-setosa']['SepalLengthCm'].min()
# Out:
# 4.3

# %%
iris[iris['Species']=='Iris-setosa']['SepalLengthCm'].max()
# Out:
# 5.8

# %% [markdown]
# ### 10. How many missing values are there in each column of the dataset?

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### 11. Create a new DataFrame containing only the samples with petal length greater than 4.5 cm.

# %%
irisnew=iris[iris['PetalLengthCm']>4.5][['PetalLengthCm']]

# %%
irisnew
# Out:
#      PetalLengthCm
# 50             4.7
# 52             4.9
# 54             4.6
# 56             4.7
# 58             4.6
# 63             4.7
# 70             4.8
# 72             4.9
# 73             4.7
# 76             4.8
# 77             5.0
# 83             5.1
# 86             4.7
# 91             4.6
# 100            6.0
# 101            5.1
# 102            5.9
# 103            5.6
# 104            5.8
# 105            6.6
# 107            6.3
# 108            5.8
# 109            6.1
# 110            5.1
# 111            5.3
# ..             ...
# 125            6.0
# 126            4.8
# 127            4.9
# 128            5.6
# 129            5.8
# 130            6.1
# 131            6.4
# 132            5.6
# 133            5.1
# 134            5.6
# 135            6.1
# 136            5.6
# 137            5.5
# 138            4.8
# 139            5.4
# 140            5.6
# 141            5.1
# 142            5.1
# 143            5.9
# 144            5.7
# 145            5.2
# 146            5.0
# 147            5.2
# 148            5.4
# 149            5.1
#
# [63 rows x 1 columns]

# %%
irisnew.dtypes
# Out:
# PetalLengthCm    float64
# dtype: object

# %% [markdown]
# ### 12. Which species of iris has the highest average petal width?

# %%
species_group=iris.groupby('Species')

# %%
species_group['PetalWidthCm'].mean().max()
# Out:
# 2.026

# %% [markdown]
# ### 13. Use the apply function to convert all petal lengths from centimeters to millimeters

# %%
def cmtomm(cm):
     return cm*10
iris['PetalLengthCm'].apply(cmtomm)
# Out:
# 0      14.0
# 1      14.0
# 2      13.0
# 3      15.0
# 4      14.0
# 5      17.0
# 6      14.0
# 7      15.0
# 8      14.0
# 9      15.0
# 10     15.0
# 11     16.0
# 12     14.0
# 13     11.0
# 14     12.0
# 15     15.0
# 16     13.0
# 17     14.0
# 18     17.0
# 19     15.0
# 20     17.0
# 21     15.0
# 22     10.0
# 23     17.0
# 24     19.0
#        ...
# 125    60.0
# 126    48.0
# 127    49.0
# 128    56.0
# 129    58.0
# 130    61.0
# 131    64.0
# 132    56.0
# 133    51.0
# 134    56.0
# 135    61.0
# 136    56.0
# 137    55.0
# 138    48.0
# 139    54.0
# 140    56.0
# 141    51.0
# 142    51.0
# 143    59.0
# 144    57.0
# 145    52.0
# 146    50.0
# 147    52.0
# 148    54.0
# 149    51.0
# Name: PetalLengthCm, Length: 150, dtype: float64

# %% [markdown]
# ### 14. Replace the species names in the Iris dataset with numeric labels as follows: "Iris setosa" with 0, "Iris versicolor" with 1, and "Iris virginica" with 2.

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_1=iris.replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris_1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# 5      6            5.4           3.9            1.7           0.4        0
# 6      7            4.6           3.4            1.4           0.3        0
# 7      8            5.0           3.4            1.5           0.2        0
# 8      9            4.4           2.9            1.4           0.2        0
# 9     10            4.9           3.1            1.5           0.1        0
# 10    11            5.4           3.7            1.5           0.2        0
# 11    12            4.8           3.4            1.6           0.2        0
# 12    13            4.8           3.0            1.4           0.1        0
# 13    14            4.3           3.0            1.1           0.1        0
# 14    15            5.8           4.0            1.2           0.2        0
# 15    16            5.7           4.4            1.5           0.4        0
# 16    17            5.4           3.9            1.3           0.4        0
# 17    18            5.1           3.5            1.4           0.3        0
# 18    19            5.7           3.8            1.7           0.3        0
# 19    20            5.1           3.8            1.5           0.3        0
# 20    21            5.4           3.4            1.7           0.2        0
# 21    22            5.1           3.7            1.5           0.4        0
# 22    23            4.6           3.6            1.0           0.2        0
# 23    24            5.1           3.3            1.7           0.5        0
# 24    25            4.8           3.4            1.9           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 125  126            7.2           3.2            6.0           1.8        2
# 126  127            6.2           2.8            4.8           1.8        2
# 127  128            6.1           3.0            4.9           1.8        2
# 128  129            6.4           2.8            5.6           2.1        2
# 129  130            7.2           3.0            5.8           1.6        2
# 130  131            7.4           2.8            6.1           1.9        2
# 131  132            7.9           3.8            6.4           2.0        2
# 132  133            6.4           2.8            5.6           2.2        2
# 133  134            6.3           2.8            5.1           1.5        2
# 134  135            6.1           2.6            5.6           1.4        2
# 135  136            7.7           3.0            6.1           2.3        2
# 136  137            6.3           3.4            5.6           2.4        2
# 137  138            6.4           3.1            5.5           1.8        2
# 138  139            6.0           3.0            4.8           1.8        2
# 139  140            6.9           3.1            5.4           2.1        2
# 140  141            6.7           3.1            5.6           2.4        2
# 141  142            6.9           3.1            5.1           2.3        2
# 142  143            5.8           2.7            5.1           1.9        2
# 143  144            6.8           3.2            5.9           2.3        2
# 144  145            6.7           3.3            5.7           2.5        2
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# ### 15. Create a new column named "species_type" in the Iris dataset that maps the species names to specific types based on their initial letters. Use "S" for species starting with 'Iris setosa', "V" for species starting with 'Iris versicolor', and "G" for species starting with 'Iris virginica'.

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species', 'sepal_length_category'],
#       dtype='object')

# %%
Species=[["SepalLengthCm","SepalWidthCm",'PetalLengthCm','PetalWidthCm','Species']]

# %%
iris["species_type"]=iris["Species"].map({'Iris-setosa':'S','Iris-versicolor':'V',"Iris-virginica":"G"})
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# ..   ...            ...           ...            ...           ...
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species sepal_length_category species_type
# 0       Iris-setosa                 Short            S
# 1       Iris-setosa                 Short            S
# 2       Iris-setosa                 Short            S
# 3       Iris-setosa                 Short            S
# 4       Iris-setosa                 Short            S
# 5       Iris-setosa                 Short            S
# 6       Iris-setosa                 Short            S
# 7       Iris-setosa                 Short            S
# 8       Iris-setosa                 Short            S
# 9       Iris-setosa                 Short            S
# 10      Iris-setosa                 Short            S
# 11      Iris-setosa                 Short            S
# 12      Iris-setosa                 Short            S
# 13      Iris-setosa                 Short            S
# 14      Iris-setosa                Medium            S
# 15      Iris-setosa                Medium            S
# 16      Iris-setosa                 Short            S
# 17      Iris-setosa                 Short            S
# 18      Iris-setosa                Medium            S
# 19      Iris-setosa                 Short            S
# 20      Iris-setosa                 Short            S
# 21      Iris-setosa                 Short            S
# 22      Iris-setosa                 Short            S
# 23      Iris-setosa                 Short            S
# 24      Iris-setosa                 Short            S
# ..              ...                   ...          ...
# 125  Iris-virginica                  Long            G
# 126  Iris-virginica                Medium            G
# 127  Iris-virginica                Medium            G
# 128  Iris-virginica                Medium            G
# 129  Iris-virginica                  Long            G
# 130  Iris-virginica                  Long            G
# 131  Iris-virginica                  Long            G
# 132  Iris-virginica                Medium            G
# 133  Iris-virginica                Medium            G
# 134  Iris-virginica                Medium            G
# 135  Iris-virginica                  Long            G
# 136  Iris-virginica                Medium            G
# 137  Iris-virginica                Medium            G
# 138  Iris-virginica                Medium            G
# 139  Iris-virginica                  Long            G
# 140  Iris-virginica                  Long            G
# 141  Iris-virginica                  Long            G
# 142  Iris-virginica                Medium            G
# 143  Iris-virginica                  Long            G
# 144  Iris-virginica                  Long            G
# 145  Iris-virginica                  Long            G
# 146  Iris-virginica                Medium            G
# 147  Iris-virginica                Medium            G
# 148  Iris-virginica                Medium            G
# 149  Iris-virginica                Medium            G
#
# [150 rows x 8 columns]

# %% [markdown]
# ### ADVANCED

# %% [markdown]
# ### 1. Create a new column named "sepal_length_category" that maps the sepal length to categories as follows: "Short" for sepal length less than 5.5 cm, "Medium" for sepal length between 5.5 cm and 6.5 cm (inclusive), and "Long" for sepal length greater than 6.5 cm.

# %%
conditions = [iris['SepalLengthCm']<5.5 , (iris['SepalLengthCm']>=5.5) & (iris['SepalLengthCm'] <=6.5),(iris['SepalLengthCm']>6.5)]
values = ['Short','Medium','Long']
iris["sepal_length_category"] = np.select(conditions,values)

# %%
iris.head(30)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
#
#    sepal_length_category species_type
# 0                  Short            S
# 1                  Short            S
# 2                  Short            S
# 3                  Short            S
# 4                  Short            S
# 5                  Short            S
# 6                  Short            S
# 7                  Short            S
# 8                  Short            S
# 9                  Short            S
# 10                 Short            S
# 11                 Short            S
# 12                 Short            S
# 13                 Short            S
# 14                Medium            S
# 15                Medium            S
# 16                 Short            S
# 17                 Short            S
# 18                Medium            S
# 19                 Short            S
# 20                 Short            S
# 21                 Short            S
# 22                 Short            S
# 23                 Short            S
# 24                 Short            S
# 25                 Short            S
# 26                 Short            S
# 27                 Short            S
# 28                 Short            S
# 29                 Short            S

# %% [markdown]
# ### 2. Use the map() function to replace the values in the "species" column with their corresponding full species names, e.g., 0 with "Iris setosa", 1 with "Iris versicolor", and 2 with "Iris virginica".

# %%
iris['Species'] = iris['Species'].map({'Iris-setosa':0 , 'Iris-versicolor':1 , 'Iris-virginica':2})

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# 5      6            5.4           3.9            1.7           0.4        0
# 6      7            4.6           3.4            1.4           0.3        0
# 7      8            5.0           3.4            1.5           0.2        0
# 8      9            4.4           2.9            1.4           0.2        0
# 9     10            4.9           3.1            1.5           0.1        0
# 10    11            5.4           3.7            1.5           0.2        0
# 11    12            4.8           3.4            1.6           0.2        0
# 12    13            4.8           3.0            1.4           0.1        0
# 13    14            4.3           3.0            1.1           0.1        0
# 14    15            5.8           4.0            1.2           0.2        0
# 15    16            5.7           4.4            1.5           0.4        0
# 16    17            5.4           3.9            1.3           0.4        0
# 17    18            5.1           3.5            1.4           0.3        0
# 18    19            5.7           3.8            1.7           0.3        0
# 19    20            5.1           3.8            1.5           0.3        0
# 20    21            5.4           3.4            1.7           0.2        0
# 21    22            5.1           3.7            1.5           0.4        0
# 22    23            4.6           3.6            1.0           0.2        0
# 23    24            5.1           3.3            1.7           0.5        0
# 24    25            4.8           3.4            1.9           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 125  126            7.2           3.2            6.0           1.8        2
# 126  127            6.2           2.8            4.8           1.8        2
# 127  128            6.1           3.0            4.9           1.8        2
# 128  129            6.4           2.8            5.6           2.1        2
# 129  130            7.2           3.0            5.8           1.6        2
# 130  131            7.4           2.8            6.1           1.9        2
# 131  132            7.9           3.8            6.4           2.0        2
# 132  133            6.4           2.8            5.6           2.2        2
# 133  134            6.3           2.8            5.1           1.5        2
# 134  135            6.1           2.6            5.6           1.4        2
# 135  136            7.7           3.0            6.1           2.3        2
# 136  137            6.3           3.4            5.6           2.4        2
# 137  138            6.4           3.1            5.5           1.8        2
# 138  139            6.0           3.0            4.8           1.8        2
# 139  140            6.9           3.1            5.4           2.1        2
# 140  141            6.7           3.1            5.6           2.4        2
# 141  142            6.9           3.1            5.1           2.3        2
# 142  143            5.8           2.7            5.1           1.9        2
# 143  144            6.8           3.2            5.9           2.3        2
# 144  145            6.7           3.3            5.7           2.5        2
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
#     sepal_length_category species_type
# 0                   Short            S
# 1                   Short            S
# 2                   Short            S
# 3                   Short            S
# 4                   Short            S
# 5                   Short            S
# 6                   Short            S
# 7                   Short            S
# 8                   Short            S
# 9                   Short            S
# 10                  Short            S
# 11                  Short            S
# 12                  Short            S
# 13                  Short            S
# 14                 Medium            S
# 15                 Medium            S
# 16                  Short            S
# 17                  Short            S
# 18                 Medium            S
# 19                  Short            S
# 20                  Short            S
# 21                  Short            S
# 22                  Short            S
# 23                  Short            S
# 24                  Short            S
# ..                    ...          ...
# 125                  Long            G
# 126                Medium            G
# 127                Medium            G
# 128                Medium            G
# 129                  Long            G
# 130                  Long            G
# 131                  Long            G
# 132                Medium            G
# 133                Medium            G
# 134                Medium            G
# 135                  Long            G
# 136                Medium            G
# 137                Medium            G
# 138                Medium            G
# 139                  Long            G
# 140                  Long            G
# 141                  Long            G
# 142                Medium            G
# 143                  Long            G
# 144                  Long            G
# 145                  Long            G
# 146                Medium            G
# 147                Medium            G
# 148                Medium            G
# 149                Medium            G
#
# [150 rows x 8 columns]

# %% [markdown]
# ### 3. Create a new column named "petal_length_label" that maps the petal length values to "Short", "Medium", or "Long" based on the quartiles of the petal length distribution (e.g., below 25th percentile: "Short", between 25th and 75th percentile: "Medium", above 75th percentile: "Long").

# %%
conditions = [iris['PetalLengthCm'] < iris['PetalLengthCm'].quantile(0.25) ,(iris['PetalLengthCm'] >= iris['PetalLengthCm'].quantile(0.25)) & (iris['PetalLengthCm'] <= iris['PetalLengthCm'].quantile(0.75)) , iris['PetalLengthCm']>= iris['PetalLengthCm'].quantile(0.75)]
values = ['Short','Medium','Long']
iris["petal_length_category"] = np.select(conditions,values)

# %%
iris.head(30)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0    1            5.1           3.5            1.4           0.2        0
# 1    2            4.9           3.0            1.4           0.2        0
# 2    3            4.7           3.2            1.3           0.2        0
# 3    4            4.6           3.1            1.5           0.2        0
# 4    5            5.0           3.6            1.4           0.2        0
# 5    6            5.4           3.9            1.7           0.4        0
# 6    7            4.6           3.4            1.4           0.3        0
# 7    8            5.0           3.4            1.5           0.2        0
# 8    9            4.4           2.9            1.4           0.2        0
# 9   10            4.9           3.1            1.5           0.1        0
# 10  11            5.4           3.7            1.5           0.2        0
# 11  12            4.8           3.4            1.6           0.2        0
# 12  13            4.8           3.0            1.4           0.1        0
# 13  14            4.3           3.0            1.1           0.1        0
# 14  15            5.8           4.0            1.2           0.2        0
# 15  16            5.7           4.4            1.5           0.4        0
# 16  17            5.4           3.9            1.3           0.4        0
# 17  18            5.1           3.5            1.4           0.3        0
# 18  19            5.7           3.8            1.7           0.3        0
# 19  20            5.1           3.8            1.5           0.3        0
# 20  21            5.4           3.4            1.7           0.2        0
# 21  22            5.1           3.7            1.5           0.4        0
# 22  23            4.6           3.6            1.0           0.2        0
# 23  24            5.1           3.3            1.7           0.5        0
# 24  25            4.8           3.4            1.9           0.2        0
# 25  26            5.0           3.0            1.6           0.2        0
# 26  27            5.0           3.4            1.6           0.4        0
# 27  28            5.2           3.5            1.5           0.2        0
# 28  29            5.2           3.4            1.4           0.2        0
# 29  30            4.7           3.2            1.6           0.2        0
#
#    species_type sepal_length_category petal_length_category
# 0             S                 Short                 Short
# 1             S                 Short                 Short
# 2             S                 Short                 Short
# 3             S                 Short                 Short
# 4             S                 Short                 Short
# 5             S                 Short                Medium
# 6             S                 Short                 Short
# 7             S                 Short                 Short
# 8             S                 Short                 Short
# 9             S                 Short                 Short
# 10            S                 Short                 Short
# 11            S                 Short                Medium
# 12            S                 Short                 Short
# 13            S                 Short                 Short
# 14            S                Medium                 Short
# 15            S                Medium                 Short
# 16            S                 Short                 Short
# 17            S                 Short                 Short
# 18            S                Medium                Medium
# 19            S                 Short                 Short
# 20            S                 Short                Medium
# 21            S                 Short                 Short
# 22            S                 Short                 Short
# 23            S                 Short                Medium
# 24            S                 Short                Medium
# 25            S                 Short                Medium
# 26            S                 Short                Medium
# 27            S                 Short                 Short
# 28            S                 Short                 Short
# 29            S                 Short                Medium

# %% [markdown]
# ### 4. Map the sepal width values to "Narrow" if they are less than 3.0 cm, and "Wide" if they are 3.0 cm or greater. Create a new column named "sepal_width_type" to store this information.

# %%
iris['sepal_width_type'] = iris['SepalWidthCm'].apply(lambda x: 'Narrow' if x < 3.0 else 'Wide')

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# 5      6            5.4           3.9            1.7           0.4        0
# 6      7            4.6           3.4            1.4           0.3        0
# 7      8            5.0           3.4            1.5           0.2        0
# 8      9            4.4           2.9            1.4           0.2        0
# 9     10            4.9           3.1            1.5           0.1        0
# 10    11            5.4           3.7            1.5           0.2        0
# 11    12            4.8           3.4            1.6           0.2        0
# 12    13            4.8           3.0            1.4           0.1        0
# 13    14            4.3           3.0            1.1           0.1        0
# 14    15            5.8           4.0            1.2           0.2        0
# 15    16            5.7           4.4            1.5           0.4        0
# 16    17            5.4           3.9            1.3           0.4        0
# 17    18            5.1           3.5            1.4           0.3        0
# 18    19            5.7           3.8            1.7           0.3        0
# 19    20            5.1           3.8            1.5           0.3        0
# 20    21            5.4           3.4            1.7           0.2        0
# 21    22            5.1           3.7            1.5           0.4        0
# 22    23            4.6           3.6            1.0           0.2        0
# 23    24            5.1           3.3            1.7           0.5        0
# 24    25            4.8           3.4            1.9           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 125  126            7.2           3.2            6.0           1.8        2
# 126  127            6.2           2.8            4.8           1.8        2
# 127  128            6.1           3.0            4.9           1.8        2
# 128  129            6.4           2.8            5.6           2.1        2
# 129  130            7.2           3.0            5.8           1.6        2
# 130  131            7.4           2.8            6.1           1.9        2
# 131  132            7.9           3.8            6.4           2.0        2
# 132  133            6.4           2.8            5.6           2.2        2
# 133  134            6.3           2.8            5.1           1.5        2
# 134  135            6.1           2.6            5.6           1.4        2
# 135  136            7.7           3.0            6.1           2.3        2
# 136  137            6.3           3.4            5.6           2.4        2
# 137  138            6.4           3.1            5.5           1.8        2
# 138  139            6.0           3.0            4.8           1.8        2
# 139  140            6.9           3.1            5.4           2.1        2
# 140  141            6.7           3.1            5.6           2.4        2
# 141  142            6.9           3.1            5.1           2.3        2
# 142  143            5.8           2.7            5.1           1.9        2
# 143  144            6.8           3.2            5.9           2.3        2
# 144  145            6.7           3.3            5.7           2.5        2
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
#     species_type sepal_length_category petal_length_category sepal_width_type
# 0              S                 Short                 Short             Wide
# 1              S                 Short                 Short             Wide
# 2              S                 Short                 Short             Wide
# 3              S                 Short                 Short             Wide
# 4              S                 Short                 Short             Wide
# 5              S                 Short                Medium             Wide
# 6              S                 Short                 Short             Wide
# 7              S                 Short                 Short             Wide
# 8              S                 Short                 Short           Narrow
# 9              S                 Short                 Short             Wide
# 10             S                 Short                 Short             Wide
# 11             S                 Short                Medium             Wide
# 12             S                 Short                 Short             Wide
# 13             S                 Short                 Short             Wide
# 14             S                Medium                 Short             Wide
# 15             S                Medium                 Short             Wide
# 16             S                 Short                 Short             Wide
# 17             S                 Short                 Short             Wide
# 18             S                Medium                Medium             Wide
# 19             S                 Short                 Short             Wide
# 20             S                 Short                Medium             Wide
# 21             S                 Short                 Short             Wide
# 22             S                 Short                 Short             Wide
# 23             S                 Short                Medium             Wide
# 24             S                 Short                Medium             Wide
# ..           ...                   ...                   ...              ...
# 125            G                  Long                  Long             Wide
# 126            G                Medium                Medium           Narrow
# 127            G                Medium                Medium             Wide
# 128            G                Medium                  Long           Narrow
# 129            G                  Long                  Long             Wide
# 130            G                  Long                  Long           Narrow
# 131            G                  Long                  Long             Wide
# 132            G                Medium                  Long           Narrow
# 133            G                Medium                Medium           Narrow
# 134            G                Medium                  Long           Narrow
# 135            G                  Long                  Long             Wide
# 136            G                Medium                  Long             Wide
# 137            G                Medium                  Long             Wide
# 138            G                Medium                Medium             Wide
# 139            G                  Long                  Long             Wide
# 140            G                  Long                  Long             Wide
# 141            G                  Long                Medium             Wide
# 142            G                Medium                Medium           Narrow
# 143            G                  Long                  Long             Wide
# 144            G                  Long                  Long             Wide
# 145            G                  Long                  Long             Wide
# 146            G                Medium                Medium           Narrow
# 147            G                Medium                  Long             Wide
# 148            G                Medium                  Long             Wide
# 149            G                Medium                Medium             Wide
#
# [150 rows x 10 columns]

# %% [markdown]
# ### 5. Use the map() function to convert the "species" column to lowercase, so all species names are in lowercase letters.

# %%
iris1=iris.copy()

# %%
iris={'Species':['Iris-setosa','Iris-versicolor','Iris-virginica']}
df=pd.DataFrame(iris)
df['Species']=df['Species'].map(str.lower)

# %%
df
# Out:
#            Species
# 0      iris-setosa
# 1  iris-versicolor
# 2   iris-virginica

# %%
iris = iris.apply(lambda column: column.map(lambda x: x.lower() if isinstance(x, str) else x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 iris = iris.apply(lambda column: column.map(lambda x: x.lower() if isinstance(x, str) else x))
#
# AttributeError: 'dict' object has no attribute 'apply'

# %% [markdown]
# ### 6. Map the "petal_area" values to "Small", "Medium", or "Large" based on custom thresholds (e.g., below 2.5 cm^2: "Small", between 2.5 cm^2 and 5.0 cm^2: "Medium", above 5.0 cm^2: "Large").

# %% [markdown]
# ### 7. Create a new column named "species_encoded" that maps the species names to unique integer values, where "Iris setosa" is encoded as 0, "Iris versicolor" as 1, and "Iris virginica" as 2.

# %%
iris['species_encoded'] = iris['Species'].map({'Iris-setosa':0 , 'Iris-versicolor':1 , 'Iris-virginica':2})
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# 5      6            5.4           3.9            1.7           0.4        0
# 6      7            4.6           3.4            1.4           0.3        0
# 7      8            5.0           3.4            1.5           0.2        0
# 8      9            4.4           2.9            1.4           0.2        0
# 9     10            4.9           3.1            1.5           0.1        0
# 10    11            5.4           3.7            1.5           0.2        0
# 11    12            4.8           3.4            1.6           0.2        0
# 12    13            4.8           3.0            1.4           0.1        0
# 13    14            4.3           3.0            1.1           0.1        0
# 14    15            5.8           4.0            1.2           0.2        0
# 15    16            5.7           4.4            1.5           0.4        0
# 16    17            5.4           3.9            1.3           0.4        0
# 17    18            5.1           3.5            1.4           0.3        0
# 18    19            5.7           3.8            1.7           0.3        0
# 19    20            5.1           3.8            1.5           0.3        0
# 20    21            5.4           3.4            1.7           0.2        0
# 21    22            5.1           3.7            1.5           0.4        0
# 22    23            4.6           3.6            1.0           0.2        0
# 23    24            5.1           3.3            1.7           0.5        0
# 24    25            4.8           3.4            1.9           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 125  126            7.2           3.2            6.0           1.8        2
# 126  127            6.2           2.8            4.8           1.8        2
# 127  128            6.1           3.0            4.9           1.8        2
# 128  129            6.4           2.8            5.6           2.1        2
# 129  130            7.2           3.0            5.8           1.6        2
# 130  131            7.4           2.8            6.1           1.9        2
# 131  132            7.9           3.8            6.4           2.0        2
# 132  133            6.4           2.8            5.6           2.2        2
# 133  134            6.3           2.8            5.1           1.5        2
# 134  135            6.1           2.6            5.6           1.4        2
# 135  136            7.7           3.0            6.1           2.3        2
# 136  137            6.3           3.4            5.6           2.4        2
# 137  138            6.4           3.1            5.5           1.8        2
# 138  139            6.0           3.0            4.8           1.8        2
# 139  140            6.9           3.1            5.4           2.1        2
# 140  141            6.7           3.1            5.6           2.4        2
# 141  142            6.9           3.1            5.1           2.3        2
# 142  143            5.8           2.7            5.1           1.9        2
# 143  144            6.8           3.2            5.9           2.3        2
# 144  145            6.7           3.3            5.7           2.5        2
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
#     sepal_length_category species_type  species_encoded
# 0                   Short          NaN              NaN
# 1                   Short          NaN              NaN
# 2                   Short          NaN              NaN
# 3                   Short          NaN              NaN
# 4                   Short          NaN              NaN
# 5                   Short          NaN              NaN
# 6                   Short          NaN              NaN
# 7                   Short          NaN              NaN
# 8                   Short          NaN              NaN
# 9                   Short          NaN              NaN
# 10                  Short          NaN              NaN
# 11                  Short          NaN              NaN
# 12                  Short          NaN              NaN
# 13                  Short          NaN              NaN
# 14                 Medium          NaN              NaN
# 15                 Medium          NaN              NaN
# 16                  Short          NaN              NaN
# 17                  Short          NaN              NaN
# 18                 Medium          NaN              NaN
# 19                  Short          NaN              NaN
# 20                  Short          NaN              NaN
# 21                  Short          NaN              NaN
# 22                  Short          NaN              NaN
# 23                  Short          NaN              NaN
# 24                  Short          NaN              NaN
# ..                    ...          ...              ...
# 125                  Long          NaN              NaN
# 126                Medium          NaN              NaN
# 127                Medium          NaN              NaN
# 128                Medium          NaN              NaN
# 129                  Long          NaN              NaN
# 130                  Long          NaN              NaN
# 131                  Long          NaN              NaN
# 132                Medium          NaN              NaN
# 133                Medium          NaN              NaN
# 134                Medium          NaN              NaN
# 135                  Long          NaN              NaN
# 136                Medium          NaN              NaN
# 137                Medium          NaN              NaN
# 138                Medium          NaN              NaN
# 139                  Long          NaN              NaN
# 140                  Long          NaN              NaN
# 141                  Long          NaN              NaN
# 142                Medium          NaN              NaN
# 143                  Long          NaN              NaN
# 144                  Long          NaN              NaN
# 145                  Long          NaN              NaN
# 146                Medium          NaN              NaN
# 147                Medium          NaN              NaN
# 148                Medium          NaN              NaN
# 149                Medium          NaN              NaN
#
# [150 rows x 9 columns]

# %% [markdown]
# ### 8. Map the "sepal_length" values to the corresponding category labels "Very Short", "Short", "Medium", "Long", and "Very Long" based on custom-defined bins.

# %% [markdown]
# ### 9. Use the map() function to replace the "species_type" values with their corresponding full names, e.g., "S" with "Iris setosa", "V" with "Iris versicolor", and "G" with "Iris virginica".

# %%
iris['species_type']=iris['species_type'].map({'S':'Iris-setosa','V':'Iris-versicolor','G':'Iris-virginica'})
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# 5      6            5.4           3.9            1.7           0.4        0
# 6      7            4.6           3.4            1.4           0.3        0
# 7      8            5.0           3.4            1.5           0.2        0
# 8      9            4.4           2.9            1.4           0.2        0
# 9     10            4.9           3.1            1.5           0.1        0
# 10    11            5.4           3.7            1.5           0.2        0
# 11    12            4.8           3.4            1.6           0.2        0
# 12    13            4.8           3.0            1.4           0.1        0
# 13    14            4.3           3.0            1.1           0.1        0
# 14    15            5.8           4.0            1.2           0.2        0
# 15    16            5.7           4.4            1.5           0.4        0
# 16    17            5.4           3.9            1.3           0.4        0
# 17    18            5.1           3.5            1.4           0.3        0
# 18    19            5.7           3.8            1.7           0.3        0
# 19    20            5.1           3.8            1.5           0.3        0
# 20    21            5.4           3.4            1.7           0.2        0
# 21    22            5.1           3.7            1.5           0.4        0
# 22    23            4.6           3.6            1.0           0.2        0
# 23    24            5.1           3.3            1.7           0.5        0
# 24    25            4.8           3.4            1.9           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 125  126            7.2           3.2            6.0           1.8        2
# 126  127            6.2           2.8            4.8           1.8        2
# 127  128            6.1           3.0            4.9           1.8        2
# 128  129            6.4           2.8            5.6           2.1        2
# 129  130            7.2           3.0            5.8           1.6        2
# 130  131            7.4           2.8            6.1           1.9        2
# 131  132            7.9           3.8            6.4           2.0        2
# 132  133            6.4           2.8            5.6           2.2        2
# 133  134            6.3           2.8            5.1           1.5        2
# 134  135            6.1           2.6            5.6           1.4        2
# 135  136            7.7           3.0            6.1           2.3        2
# 136  137            6.3           3.4            5.6           2.4        2
# 137  138            6.4           3.1            5.5           1.8        2
# 138  139            6.0           3.0            4.8           1.8        2
# 139  140            6.9           3.1            5.4           2.1        2
# 140  141            6.7           3.1            5.6           2.4        2
# 141  142            6.9           3.1            5.1           2.3        2
# 142  143            5.8           2.7            5.1           1.9        2
# 143  144            6.8           3.2            5.9           2.3        2
# 144  145            6.7           3.3            5.7           2.5        2
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
#     sepal_length_category species_type
# 0                   Short          NaN
# 1                   Short          NaN
# 2                   Short          NaN
# 3                   Short          NaN
# 4                   Short          NaN
# 5                   Short          NaN
# 6                   Short          NaN
# 7                   Short          NaN
# 8                   Short          NaN
# 9                   Short          NaN
# 10                  Short          NaN
# 11                  Short          NaN
# 12                  Short          NaN
# 13                  Short          NaN
# 14                 Medium          NaN
# 15                 Medium          NaN
# 16                  Short          NaN
# 17                  Short          NaN
# 18                 Medium          NaN
# 19                  Short          NaN
# 20                  Short          NaN
# 21                  Short          NaN
# 22                  Short          NaN
# 23                  Short          NaN
# 24                  Short          NaN
# ..                    ...          ...
# 125                  Long          NaN
# 126                Medium          NaN
# 127                Medium          NaN
# 128                Medium          NaN
# 129                  Long          NaN
# 130                  Long          NaN
# 131                  Long          NaN
# 132                Medium          NaN
# 133                Medium          NaN
# 134                Medium          NaN
# 135                  Long          NaN
# 136                Medium          NaN
# 137                Medium          NaN
# 138                Medium          NaN
# 139                  Long          NaN
# 140                  Long          NaN
# 141                  Long          NaN
# 142                Medium          NaN
# 143                  Long          NaN
# 144                  Long          NaN
# 145                  Long          NaN
# 146                Medium          NaN
# 147                Medium          NaN
# 148                Medium          NaN
# 149                Medium          NaN
#
# [150 rows x 8 columns]

# %% [markdown]
# ### 10. Create a new column named "petal_width_type" that maps the petal width values to "Narrow", "Medium", or "Wide" based on custom-defined bins

# %% [markdown]
# ### TITANIC
# ADVANCED

# %% [markdown]
# ### 1. What was the overall survival rate of passengers on the Titanic?

# %%
titanic=pd.read_csv('Titanic-Dataset.xls',index_col='PassengerId')
titanic.head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 13                              Saundercock, Mr. William Henry    male  20.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 17                                        Rice, Master. Eugene    male   2.0
# 18                                Williams, Mr. Charles Eugene    male   NaN
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 20                                     Masselmani, Mrs. Fatima  female   NaN
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C
# 11               1      1           PP 9549  16.7000    G6        S
# 12               0      0            113783  26.5500  C103        S
# 13               0      0         A/5. 2151   8.0500   NaN        S
# 14               1      5            347082  31.2750   NaN        S
# 15               0      0            350406   7.8542   NaN        S
# 16               0      0            248706  16.0000   NaN        S
# 17               4      1            382652  29.1250   NaN        Q
# 18               0      0            244373  13.0000   NaN        S
# 19               1      0            345763  18.0000   NaN        S
# 20               0      0              2649   7.2250   NaN        C

# %%
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic[titanic['Survived']==1]['Survived'].value_counts(normalize=True)
# Out:
# 1    1.0
# Name: Survived, dtype: float64

# %%
titanic['Survived'].value_counts(1)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %% [markdown]
# ### 2. What was the survival rate for male and female passengers separately?

# %%
total_passengers=len(titanic)
total_survivors=titanic['Survived'].sum()
survival_rate = total_passengers/total_survivors

# %%
survival_rate
# Out:
# 2.6052631578947367

# %% [markdown]
# ### 3. How many passengers survived in each passenger class (1st, 2nd, and 3rd class)?

# %%
passenger_survived = titanic.groupby('Pclass')
passenger_survived['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %% [markdown]
# ### 4. What was the average age of survivors and non-survivors?`

# %%
survived_group=titanic.groupby("Survived")
(survived_group["Age"]).mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %% [markdown]
# ### 5. Did the passenger class have any impact on the survival rate? Compare survival rates for each class.

# %% [markdown]
# ### 6. How many passengers had siblings/spouses aboard? Did having siblings/spouses increase the chances of survival?

# %% [markdown]
# ### 7. How many passengers had parents/children aboard? Did having parents/children increase the chances of survival?

# %% [markdown]
# ### 8. Did the port of embarkation affect the survival rate? Compare survival rates for each embarkation port (C - Cherbourg, Q - Queenstown, S - Southampton).

# %% [markdown]
# ### 9. Is there any correlation between fare paid and survival rate?

# %% [markdown]
# ### 10. What was the distribution of passengers' ages within each passenger class?
